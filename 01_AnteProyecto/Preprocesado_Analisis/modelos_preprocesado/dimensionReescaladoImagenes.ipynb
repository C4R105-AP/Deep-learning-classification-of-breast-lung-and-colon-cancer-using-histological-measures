# %%
from PIL import Image

# %%
# Abrir la imagen del dataset de celulas mamarias
image1 = Image.open(r"C:\Users\lacer\OneDrive\Escritorio\ejercicios\TFM\8863\0\8863_idx5_x51_y1251_class0.png") #Poner ubicación de la imagen

# Obtener los píxeles de la imagen
pixeles = image1.load

# %%
# Obtener las dimensiones de los píxeles
width, height = image1.size

print("Ancho:", width)
print("Alto:", height)
# Out:
# Ancho: 50
# Alto: 50

# %%
# Abrir la imagen del dataset de colon y pulmones
image2 = Image.open(r"C:\Users\lacer\OneDrive\Escritorio\ejercicios\TFM2\lung_image_sets\lung_aca\lungaca1.jpeg") #Poner ubicación de la imagen

# Obtener los píxeles de la imagen
pixeles = image2.load

# %%
# Obtener las dimensiones de los píxeles
width, height = image2.size

print("Ancho:", width)
print("Alto:", height)
# Out:
# Ancho: 768
# Alto: 768

# %%
#Redimensionamos la foto de células mamarias
# Redimensionar la imagen a 768x768
new_size = (768, 768)
resized_image = image1.resize(new_size)

# Guardar la imagen redimensionada
#resized_image.save("Images/test1.jpg")

# %%
# Obtener las dimensiones de los píxeles
width, height = image2.size

print("Foto reescalada (768x768)")
print("Ancho:", width)
print("Alto:", height)
# Out:
# Foto reescalada (768x768)
# Ancho: 768
# Alto: 768
